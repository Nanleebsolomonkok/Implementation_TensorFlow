# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#softmax function
def softmax(z):
  ez = np.exp(z)
  sum = ez / np.sum(ez)
  return sum

#dataset
centers = [[-5, 2],
           [-2, -2],
           [1, 2],
           [5, -2]]

X_train = np.array([
                        [1.56,  0.85],
                        [-0.84, -1.95],
                        [-4.09,  0.68],
                        [-0.84, -1.95],
                        [ 5.04, -2.92],
                        [ 0.38,  1.5 ]])
Y_train = np.array([0, 1, 2, 1, 3, 2])

print(X_train)

#not preferred
#compute model
model = Sequential([
     Dense(4, input_dim=2, activation='relu'),
     Dense(4, activation='relu'),
     Dense(4, activation='softmax')
])

#cost and loss
model.compile(
    loss = tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
)

model.fit(X_train, Y_train, epochs=100)
#not accurate
non_preferred = model.predict(X_train)
print("prediction = \n ", non_preferred[:2])
print("largest_value =", np.max(non_preferred ), ", smallest_value =", np.min(non_preferred))

#preferred
model = Sequential([
     Dense(4, input_dim=2, activation='relu'),
     Dense(4, activation='relu'),
     Dense(4, activation="linear")
])

model.compile(
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
)

model.fit(X_train, Y_train, epochs= 10)

#predict
preferred = model.predict(X_train)
print("Preferred_prediction: \n", preferred[:2])
print("largest_value =", np.max(preferred), ", smallest_value =", np.min(preferred))

for i in range(5):
    print( f"{preferred[i]}, category: {np.argmax(preferred[i])}")
# Out:
# [[ 1.56  0.85]
#  [-0.84 -1.95]
#  [-4.09  0.68]
#  [-0.84 -1.95]
#  [ 5.04 -2.92]
#  [ 0.38  1.5 ]]
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.4492
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.4279
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 1.4093
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.3918
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.3756
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.3610
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 1.3473
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.3342
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.3215
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.3088
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.2962
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.2808
# Epoch 13/100
# ...
